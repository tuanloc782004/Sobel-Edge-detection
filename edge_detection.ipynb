# %%
import numpy as np
import scipy.signal as sig
import matplotlib.pyplot as plt
from imageio import imread

# %%
# Load image
def load_image(path):
    image = imread(path, mode='F')  
    return image

# %%
# Apply Sobel filter
def apply_sobel_filter(image):
    sobel_x = np.array([[-1, 0, 1], [-2, 0, 2], [-1, 0, 1]])
    sobel_y = np.array([[-1, -2, -1], [0, 0, 0], [1, 2, 1]])
    edge_x = sig.convolve2d(image, sobel_x, mode='same')
    edge_y = sig.convolve2d(image, sobel_y, mode='same')
    edge_magnitude = np.sqrt(edge_x**2 + edge_y**2)
    return edge_magnitude

# %%
# Plot results
def plot_results(original, processed):
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.title("Ảnh gốc")
    plt.imshow(original, cmap='gray')
    plt.axis("off")

    plt.subplot(1, 2, 2)
    plt.title("Ảnh tách biên")
    plt.imshow(processed, cmap='gray')
    plt.axis("off")
    plt.show()

# %%
# Run program
image = load_image('input_image.jpg')
edge_image = apply_sobel_filter(image)
plot_results(image, edge_image)
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_13480\2486998467.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imread(path, mode='F')
